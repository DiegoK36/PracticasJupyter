# %% [markdown]
# # Prueba de que mi PC es una mie...

# %% [markdown]
# ### Before

# %%
from IPython import display as dp

# %%
dp.Image("cpu.png")

# %% [markdown]
# ### After

# %%
def fib (n):
    if n in {0,1}:
        return 1
    else:
        return (fib(n-1)+fib(n-2))

# %%
fib(10)
# Out:
# 89

# %%
dp.Image("cpu2.png")

# %%
import multiprocessing as mp, threading as th

# %%
th.active_count()
# Out:
# 6

# %%
th.enumerate()
# Out:
# [<_MainThread(MainThread, started 5976)>,
#  <Thread(IOPub, started daemon 5160)>,
#  <Heartbeat(Heartbeat, started daemon 16900)>,
#  <ControlThread(Control, started daemon 6856)>,
#  <HistorySavingThread(IPythonHistorySavingThread, started 11520)>,
#  <ParentPollerWindows(Thread-4, started daemon 17400)>]

# %%
ProcessPoolExecutor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 ProcessPoolExecutor
#
# NameError: name 'ProcessPoolExecutor' is not defined
